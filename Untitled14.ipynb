# %%
from deepface import DeepFace
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread(r"C:\Users\gopiv\OneDrive\Pictures\Camera Roll\WIN_20230314_16_44_15_Pro.jpg")

# %%
plt.imshow(img[:,:,::-1])
plt.show()

# %%
result=DeepFace.analyze(img,actions=['emotion'])
print(result)
# Out:
# Action: emotion: 100%|██████████| 1/1 [00:00<00:00, 10.26it/s]
# [{'emotion': {'angry': 9.149755796147419e-18, 'disgust': 2.441593784817612e-27, 'fear': 4.848975398258605e-06, 'happy': 4.089687695304527e-12, 'sad': 1.273476194786943e-06, 'surprise': 1.6038151898219328e-13, 'neutral': 99.99998807907247}, 'dominant_emotion': 'neutral', 'region': {'x': 825, 'y': 339, 'w': 378, 'h': 378}}]
